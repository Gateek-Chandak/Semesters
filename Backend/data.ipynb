# %%
import numpy as np 
import pandas as pd

# %%
stat_table = pd.read_csv('csv/Stat230_table.csv')
math_table = pd.read_csv('csv/Math239_table.csv')

# %%
math_table
# Out:
#                                   Component Value
# 0  Individual assignments (Best 7 out of 9)   20%
# 1                              Midterm exam   30%
# 2                                Final exam   50%

# %%
stat_table
# Out:
#                         Component          Value
# 0  Tutorial Quizzes (best 3 of 5)  21% (7% each)
# 1                  Best Term Test            27%
# 2                 Worst Term Test            12%
# 3                      Final Exam            40%

# %%
stat_schedule = pd.read_csv('csv/Stat230_Schedule.csv')
stat_schedule
# Out:
#                             Week  \
# 0          Week 1\n(Sept. 4 - 6)
# 1         Week 2\n(Sept. 9 - 13)
# 2        Week 3\n(Sept. 16 - 20)
# 3        Week 4\n(Sept. 23 - 27)
# 4   Week 5\n(Sept. 30 - Oct.\n4)
# 5                           Week
# 6          Week 6\n(Oct. 7 - 11)
# 7                            NaN
# 8         Week 7\n(Oct. 21 - 25)
# 9    Week 8\n(Oct. 28 - Nov.\n1)
# 10                          Week
# 11          Week 9\n(Nov. 4 - 8)
# 12       Week 10\n(Nov. 11 - 15)
# 13        Week 11\n(Nov.18 - 22)
# 14       Week 12\n(Nov. 25 - 29)
# 15                          Week
# 16             Week 13\n(Dec. 2)
# 17                     Dec. 6-19
#
#                                            Key Topics             Sections  \
# 0   Course Outline\nRegister for Piazza\nDefinitio...             1.1, 1.2
# 1   Probability/Odds of an\nEvent, Addition and\nM...             1.2, 1.3
# 2   Review of Set Theory, De\nMorganʼs Laws, Addit...        2.1, 2.2, 2.3
# ...
